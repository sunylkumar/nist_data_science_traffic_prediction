# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
from sklearn.metrics import accuracy_score
import operator
import warnings
warnings.filterwarnings("ignore")

# %%
# Accidents = 10
# Precipitation = 10
# Roadworks = 3
# Devices = 10 (19)
# obstruction  = 10 (8)
# Traffic = 10-(27),

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()

# %%
length = 11 # value is 11 for predicting for 2014

# %%
eventdf = pd.read_csv('accidentsAndIncidents.csv').drop(['Unnamed: 0'], axis=1)
clf = tree.DecisionTreeClassifier(max_depth=8)

year = np.array([2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]).reshape(-1,1)
event = eventdf.as_matrix()

length = 11 # value is 11 for predicting for 2014

# %%
#2014

xtrain = year[0:11]
ytrain = event[:, 0:11]

# %%
xtest = np.array([2014]).reshape(-1,1)

# %%
predict = []
sampleSize= 10
for i in range(sampleSize):
    clf.fit(xtrain, ytrain[i])
    predict.append(clf.predict(xtest)[0])
    #print reg.score(xtest, ytest[i])

# %%
predict
# Out:
# [278, 10, 102, 237, 496, 25, 204, 336, 727, 13]

# %%
predict
# Out:
# [278, 10, 102, 237, 496, 25, 204, 336, 727, 13]

# %%
predict
# Out:
# [278, 10, 102, 237, 496, 25, 204, 336, 727, 13]

# %%
#2014

np.sqrt((np.array(map(operator.sub, predict, ytest[:sampleSize]))**2).mean())
# Out:
# 367.57699873631918

# %%
predictA = []
sampleSize= 10
for i in range(sampleSize):
    clf.fit(xtrain, ytrain[i])
    predictA.append(clf.predict(xtest))
    #print reg.score(xtest, ytest[i])
    
accidentRMS = np.sqrt((np.array(map(operator.sub, predict, ytest[:sampleSize]))**2).mean())

# %%
np.array(map(operator.sub, predict, ytest[:sampleSize]))**2
# Out:
#   File "<ipython-input-414-61697fce6ba7>", line 1
#     np.array(map(operator.sub, predict, ytest[:sampleSize]))**2)
#                                                                ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(range(100), predict[:100], 'g-')
ax2.plot(range(100), ytest[:100], 'r-')

# %%
all(i >=0 for i in predict)
# Out:
# True
